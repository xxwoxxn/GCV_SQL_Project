# %%
import sqlite3
import os
import csv
import pandas as pd

# %%
csv_dictionary = 'schema'
os.chdir(csv_directory)

database_file = 'CRM.db'
conn = sqlite3.connect(database_file)
cursor = conn.cursor()

print(f"database file: {database_file} uploaded.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 csv_dictionary = 'schema'
# ----> 2 os.chdir(csv_directory)
#       4 database_file = 'CRM.db'
#       5 conn = sqlite3.connect(database_file)
#
# NameError: name 'csv_directory' is not defined
