# %%
import sqlite3
import os
import csv
import pandas as pd

# %%
csv_directory = 'schema' 
os.chdir(csv_directory)
database_file = 'CRM.db'
conn = sqlite3.connect(database_file)
cursor = conn.cursor()

print(f"database file: {database_file} uploaded.")
# Out:
# database file: CRM.db uploaded.
